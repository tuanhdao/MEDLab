# %% [markdown]
# <a href="https://colab.research.google.com/github/tuanhdao/FYRE/blob/main/FYRE_Behavioral_data_Voting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import packages
import json
import pandas as pd
import csv
from IPython.display import display

#Open JSON file
with open("/content/FYRE1022_survivor-1024 (1).json", "r") as read_file:
    data = json.load(read_file)
    coplayers = data["coplayers"]
#Get FYRE ID
    subject_info = data["subject"]
#Voting behavior of coplayer
#First get all the voting patterns of each coplayer to store as a list 
#Then replace 0 for Neutral, 1 for Keep and -1 for Kick
#Indifferent coplayers
    indiff = data["coplayers"]["indiff"]["votes"]
    indiff_list = list(indiff)
    for index,item in enumerate(indiff_list):
      if item == -1:
          indiff_list[index] = "Kick"
      if item == 0:
        indiff_list[index] = "Neutral"
      if item == 1:
        indiff_list[index] = "Keep"   
    indiff_df = pd.DataFrame(indiff_list)
#Mean coplayers
    mean1_df = pd.DataFrame(mean1_list)
    mean1 = data["coplayers"]["mean1"]["votes"]
    mean1_list = list(mean1)
    for index,item in enumerate(mean1_list):
      if item == -1:
          mean1_list[index] = "Kick"
      if item == 0:
        mean1_list[index] = "Neutral"
      if item == 1:
        mean1_list[index] = "Keep"   
    mean1_df = pd.DataFrame(mean1_list)
    mean2 = data["coplayers"]["mean2"]["votes"]
    mean2_list = list(mean2)
    for index,item in enumerate(mean2_list):
      if item == -1:
          mean2_list[index] = "Kick"
      if item == 0:
        mean2_list[index] = "Neutral"
      if item == 1:
        mean2_list[index] = "Keep"   
    mean2_df = pd.DataFrame(mean2_list)
    mean3 = data["coplayers"]["mean3"]["votes"]
    mean3_list = list(mean3)
    for index,item in enumerate(mean3_list):
      if item == -1:
          mean3_list[index] = "Kick"
      if item == 0:
        mean3_list[index] = "Neutral"
      if item == 1:
        mean3_list[index] = "Keep"   
    mean3_df = pd.DataFrame(mean3_list)
# Nice coplayers
    nice1 = data["coplayers"]["nice1"]["votes"]
    nice1_list = list(nice1)
    for index,item in enumerate(nice1_list):
      if item == -1:
          nice1_list[index] = "Kick"
      if item == 0:
        nice1_list[index] = "Neutral"
      if item == 1:
        nice1_list[index] = "Keep"   
    nice1_df = pd.DataFrame(nice1_list)
    nice2 = data["coplayers"]["nice2"]["votes"]
    nice2_list = list(nice2)
    for index,item in enumerate(nice2_list):
      if item == -1:
          nice2_list[index] = "Kick"
      if item == 0:
        nice2_list[index] = "Neutral"
      if item == 1:
        nice2_list[index] = "Keep"   
    nice2_df = pd.DataFrame(nice2_list)
    nice3 = data["coplayers"]["nice3"]["votes"]
    nice3_list = list(nice3)
    for index,item in enumerate(nice3_list):
      if item == -1:
          nice3_list[index] = "Kick"
      if item == 0:
        nice3_list[index] = "Neutral"
      if item == 1:
        nice3_list[index] = "Keep"   
    nice3_df = pd.DataFrame(nice3_list)
#Expendables
    xpendable_nra = data["coplayers"]["xpendable_nra"]["votes"]
    xpendable_nra_list = list(xpendable_nra)
    for index,item in enumerate(xpendable_nra_list):
      if item == -1:
          xpendable_nra_list[index] = "Kick"
      if item == 0:
        xpendable_nra_list[index] = "Neutral"
      if item == 1:
        xpendable_nra_list[index] = "Keep"   
    xpendable_nra_df = pd.DataFrame(xpendable_nra_list)
    xpendable_arn = data["coplayers"]["xpendable_arn"]["votes"]
    xpendable_arn_list = list(xpendable_arn)
    for index,item in enumerate(xpendable_arn_list):
      if item == -1:
          xpendable_arn_list[index] = "Kick"
      if item == 0:
        xpendable_arn_list[index] = "Neutral"
      if item == 1:
        xpendable_arn_list[index] = "Keep"   
    xpendable_arn_df = pd.DataFrame(xpendable_arn_list)
    xpendable_anr = data["coplayers"]["xpendable_anr"]["votes"]
    xpendable_anr_list = list(xpendable_anr)
    for index,item in enumerate(xpendable_anr_list):
      if item == -1:
          xpendable_anr_list[index] = "Kick"
      if item == 0:
        xpendable_anr_list[index] = "Neutral"
      if item == 1:
        xpendable_anr_list[index] = "Keep"   
    xpendable_anr_df = pd.DataFrame(xpendable_anr_list)
    xpendable_nar = data["coplayers"]["xpendable_nar"]["votes"]
    xpendable_nar_list = list(xpendable_nar)
    for index,item in enumerate(xpendable_nar_list):
      if item == -1:
          xpendable_nar_list[index] = "Kick"
      if item == 0:
        xpendable_nar_list[index] = "Neutral"
      if item == 1:
        xpendable_nar_list[index] = "Keep"   
    xpendable_nar_df = pd.DataFrame(xpendable_nar_list)
    xpendable_ran = data["coplayers"]["xpendable_ran"]["votes"]
    xpendable_ran_list = list(xpendable_ran)
    for index,item in enumerate(xpendable_ran_list):
      if item == -1:
          xpendable_ran_list[index] = "Kick"
      if item == 0:
        xpendable_ran_list[index] = "Neutral"
      if item == 1:
        xpendable_ran_list[index] = "Keep"   
    xpendable_ran_df = pd.DataFrame(xpendable_ran_list)
    xpendable_rna = data["coplayers"]["xpendable_rna"]["votes"]
    xpendable_rna_list = list(xpendable_rna)
    for index,item in enumerate(xpendable_rna_list):
      if item == -1:
          xpendable_rna_list[index] = "Kick"
      if item == 0:
        xpendable_rna_list[index] = "Neutral"
      if item == 1:
        xpendable_rna_list[index] = "Keep"   
    xpendable_rna_df = pd.DataFrame(xpendable_rna_list)
    xpendable_rna = data["coplayers"]["xpendable_rna"]["votes"]
    xpendable_rna_list = list(xpendable_rna)
    for index,item in enumerate(xpendable_rna_list):
      if item == -1:
          xpendable_rna_list[index] = "Kick"
      if item == 0:
        xpendable_rna_list[index] = "Neutral"
      if item == 1:
        xpendable_rna_list[index] = "Keep"   
    xpendable_rna_df = pd.DataFrame(xpendable_rna_list)
    xpendable_rna = data["coplayers"]["xpendable_rna"]["votes"]
    xpendable_rna_list = list(xpendable_rna)
    for index,item in enumerate(xpendable_rna_list):
      if item == -1:
          xpendable_rna_list[index] = "Kick"
      if item == 0:
        xpendable_rna_list[index] = "Neutral"
      if item == 1:
        xpendable_rna_list[index] = "Keep"   
    xpendable_rna_df = pd.DataFrame(xpendable_rna_list)
#Voting behavior of participant across 6 rounds
    subject_votes_1 = data["round"][0]["subject_votes"]
    subject_votes_2 = data["round"][1]["subject_votes"]
    subject_votes_3 = data["round"][2]["subject_votes"]
    subject_votes_4 = data["round"][3]["subject_votes"]
    subject_votes_5 = data["round"][4]["subject_votes"]
    subject_votes_6 = data["round"][5]["subject_votes"]
#Create a list of all participant votes for all coplayers
    coplayer_round1 = list(subject_votes_1.keys())
    coplayer_round2 = list(subject_votes_2.keys())
    coplayer_round3 = list(subject_votes_3.keys())
    coplayer_round4 = list(subject_votes_4.keys())
    coplayer_round5 = list(subject_votes_5.keys())
    coplayer_round6 = list(subject_votes_6.keys())
    vote1_list = list(subject_votes_1.values())
    vote2_list = list(subject_votes_2.values())
    vote3_list = list(subject_votes_3.values())
    vote4_list = list(subject_votes_4.values())
    vote5_list = list(subject_votes_5.values())
    vote6_list = list(subject_votes_6.values())
#Create dataframes for voting behavior and type of coplayer
    vote1_df = pd.DataFrame(vote1_list)
    vote2_df = pd.DataFrame(vote2_list)
    vote3_df = pd.DataFrame(vote3_list)
    vote4_df = pd.DataFrame(vote4_list)
    vote5_df = pd.DataFrame(vote5_list)
    vote6_df = pd.DataFrame(vote6_list)
    cop_type1_df = pd.DataFrame(coplayer_round1)
    cop_type2_df = pd.DataFrame(coplayer_round2)
    cop_type3_df = pd.DataFrame(coplayer_round3)
    cop_type4_df = pd.DataFrame(coplayer_round4)
    cop_type5_df = pd.DataFrame(coplayer_round5)
    cop_type6_df = pd.DataFrame(coplayer_round6)
    
#Merge participant voting behavior and type of coplayer
    voting_round1 = cop_type1_df.reset_index(drop=True).merge(vote1_df.reset_index(drop=True), 
                                                            left_index=True, right_index=True)
    voting_round1.insert(0, "Round", 1)
    voting_round2 = cop_type2_df.reset_index(drop=True).merge(vote2_df.reset_index(drop=True), 
                                                            left_index=True, right_index=True)
    voting_round2.insert(0, "Round", 2)
    voting_round3 = cop_type3_df.reset_index(drop=True).merge(vote3_df.reset_index(drop=True), 
                                                            left_index=True, right_index=True)
    voting_round3.insert(0, "Round", 3)
    voting_round4 = cop_type4_df.reset_index(drop=True).merge(vote4_df.reset_index(drop=True), 
                                                            left_index=True, right_index=True)
    voting_round4.insert(0, "Round", 4)
    voting_round5 = cop_type5_df.reset_index(drop=True).merge(vote5_df.reset_index(drop=True), 
                                                            left_index=True, right_index=True)
    voting_round5.insert(0, "Round", 5)
    voting_round6 = cop_type6_df.reset_index(drop=True).merge(vote6_df.reset_index(drop=True), 
                                                            left_index=True, right_index=True)
    voting_round6.insert(0, "Round", 6)
    vote_frame = [voting_round1, voting_round2, voting_round3, voting_round4, voting_round5,voting_round6]
    res_vote = pd.concat(vote_frame, axis = 0)
    vote_df = pd.DataFrame(res_vote)
#Rename columns and add ID
    vote_df.insert(0, "Subject ID", subject_info)
#Now add vote of each coplayer across rounds
#First convert dataframe to list, then use a for loop and an if statement to figure out where to add which value
    vote_list = vote_df.values.tolist()
    for index, item in enumerate(vote_list):
      if vote_list[index][1]== 1 and vote_list[index][2] == "indiff":
        item.append(indiff_list[0])
      if vote_list[index][1]== 2 and vote_list[index][2] == "indiff":
        item.append(indiff_list[1])
      if vote_list[index][1]== 3 and vote_list[index][2] == "indiff":
        item.append(indiff_list[2])
      if vote_list[index][1]== 4 and vote_list[index][2] == "indiff":
        item.append(indiff_list[3])
      if vote_list[index][1]== 5 and vote_list[index][2] == "indiff":
        item.append(indiff_list[4])
      if vote_list[index][1]== 6 and vote_list[index][2] == "indiff":
        item.append(indiff_list[5])
      if vote_list[index][1]== 1 and vote_list[index][2] == "mean1":
        item.append(mean1_list[0])
      if vote_list[index][1]== 2 and vote_list[index][2] == "mean1":
        item.append(mean1_list[1])
      if vote_list[index][1]== 3 and vote_list[index][2] == "mean1":
        item.append(mean1_list[2])
      if vote_list[index][1]== 4 and vote_list[index][2] == "mean1":
        item.append(mean1_list[3])
      if vote_list[index][1]== 5 and vote_list[index][2] == "mean1":
        item.append(mean1_list[4])
      if vote_list[index][1]== 6 and vote_list[index][2] == "mean1":
        item.append(mean1_list[5])
      if vote_list[index][1]== 1 and vote_list[index][2] == "mean2":
        item.append(mean2_list[0])
      if vote_list[index][1]== 2 and vote_list[index][2] == "mean2":
        item.append(mean2_list[1])
      if vote_list[index][1]== 3 and vote_list[index][2] == "mean2":
        item.append(mean2_list[2])
      if vote_list[index][1]== 4 and vote_list[index][2] == "mean2":
        item.append(mean2_list[3])
      if vote_list[index][1]== 5 and vote_list[index][2] == "mean2":
        item.append(mean2_list[4])
      if vote_list[index][1]== 6 and vote_list[index][2] == "mean2":
        item.append(mean2_list[5])
      if vote_list[index][1]== 1 and vote_list[index][2] == "mean3":
        item.append(mean3_list[0])
      if vote_list[index][1]== 2 and vote_list[index][2] == "mean3":
        item.append(mean3_list[1])
      if vote_list[index][1]== 3 and vote_list[index][2] == "mean3":
        item.append(mean3_list[2])
      if vote_list[index][1]== 4 and vote_list[index][2] == "mean3":
        item.append(mean3_list[3])
      if vote_list[index][1]== 5 and vote_list[index][2] == "mean3":
        item.append(mean3_list[4])
      if vote_list[index][1]== 6 and vote_list[index][2] == "mean3":
        item.append(mean3_list[5])
      if vote_list[index][1]== 1 and vote_list[index][2] == "nice1":
        item.append(nice1_list[0])
      if vote_list[index][1]== 2 and vote_list[index][2] == "nice1":
        item.append(nice1_list[1])
      if vote_list[index][1]== 3 and vote_list[index][2] == "nice1":
        item.append(nice1_list[2])
      if vote_list[index][1]== 4 and vote_list[index][2] == "nice1":
        item.append(nice1_list[3])
      if vote_list[index][1]== 5 and vote_list[index][2] == "nice1":
        item.append(nice1_list[4])
      if vote_list[index][1]== 6 and vote_list[index][2] == "nice1":
        item.append(nice1_list[5])
      if vote_list[index][1]== 1 and vote_list[index][2] == "nice2":
        item.append(nice2_list[0])
      if vote_list[index][1]== 2 and vote_list[index][2] == "nice2":
        item.append(nice2_list[1])
      if vote_list[index][1]== 3 and vote_list[index][2] == "nice2":
        item.append(nice2_list[2])
      if vote_list[index][1]== 4 and vote_list[index][2] == "nice2":
        item.append(nice2_list[3])
      if vote_list[index][1]== 5 and vote_list[index][2] == "nice2":
        item.append(nice2_list[4])
      if vote_list[index][1]== 6 and vote_list[index][2] == "nice2":
        item.append(nice2_list[5])
      if vote_list[index][1]== 1 and vote_list[index][2] == "nice3":
        item.append(nice3_list[0])
      if vote_list[index][1]== 2 and vote_list[index][2] == "nice3":
        item.append(nice3_list[1])
      if vote_list[index][1]== 3 and vote_list[index][2] == "nice3":
        item.append(nice3_list[2])
      if vote_list[index][1]== 4 and vote_list[index][2] == "nice3":
        item.append(nice3_list[3])
      if vote_list[index][1]== 5 and vote_list[index][2] == "nice3":
        item.append(nice3_list[4])
      if vote_list[index][1]== 6 and vote_list[index][2] == "nice3":
        item.append(nice3_list[5])
      if vote_list[index][1]== 1 and vote_list[index][2] == "xpendable_nra":
        item.append(xpendable_nra_list[0])
      if vote_list[index][1]== 2 and vote_list[index][2] == "xpendable_nra":
        item.append(xpendable_nra_list[1])
      if vote_list[index][1]== 3 and vote_list[index][2] == "xpendable_nra":
        item.append(xpendable_nra_list[2])
      if vote_list[index][1]== 4 and vote_list[index][2] == "xpendable_nra":
        item.append(xpendable_nra_list[3])
      if vote_list[index][1]== 5 and vote_list[index][2] == "xpendable_nra":
        item.append(xpendable_nra_list[4])
      if vote_list[index][1]== 6 and vote_list[index][2] == "xpendable_nra":
        item.append(xpendable_nra_list[5])
      if vote_list[index][1]== 1 and vote_list[index][2] == "xpendable_arn":
        item.append(xpendable_arn_list[0])
      if vote_list[index][1]== 2 and vote_list[index][2] == "xpendable_arn":
        item.append(xpendable_arn_list[1])
      if vote_list[index][1]== 3 and vote_list[index][2] == "xpendable_arn":
        item.append(xpendable_arn_list[2])
      if vote_list[index][1]== 4 and vote_list[index][2] == "xpendable_arn":
        item.append(xpendable_arn_list[3])
      if vote_list[index][1]== 5 and vote_list[index][2] == "xpendable_arn":
        item.append(xpendable_arn_list[4])
      if vote_list[index][1]== 6 and vote_list[index][2] == "xpendable_arn":
        item.append(xpendable_arn_list[5])
      if vote_list[index][1]== 1 and vote_list[index][2] == "xpendable_anr":
        item.append(xpendable_anr_list[0])
      if vote_list[index][1]== 2 and vote_list[index][2] == "xpendable_anr":
        item.append(xpendable_anr_list[1])
      if vote_list[index][1]== 3 and vote_list[index][2] == "xpendable_anr":
        item.append(xpendable_anr_list[2])
      if vote_list[index][1]== 4 and vote_list[index][2] == "xpendable_anr":
        item.append(xpendable_anr_list[3])
      if vote_list[index][1]== 5 and vote_list[index][2] == "xpendable_anr":
        item.append(xpendable_anr_list[4])
      if vote_list[index][1]== 6 and vote_list[index][2] == "xpendable_anr":
        item.append(xpendable_anr_list[5])
      if vote_list[index][1]== 1 and vote_list[index][2] == "xpendable_nar":
        item.append(xpendable_nar_list[0])
      if vote_list[index][1]== 2 and vote_list[index][2] == "xpendable_nar":
        item.append(xpendable_nar_list[1])
      if vote_list[index][1]== 3 and vote_list[index][2] == "xpendable_nar":
        item.append(xpendable_nar_list[2])
      if vote_list[index][1]== 4 and vote_list[index][2] == "xpendable_nar":
        item.append(xpendable_nar_list[3])
      if vote_list[index][1]== 5 and vote_list[index][2] == "xpendable_nar":
        item.append(xpendable_nar_list[4])
      if vote_list[index][1]== 6 and vote_list[index][2] == "xpendable_nar":
        item.append(xpendable_nar_list[5])
      if vote_list[index][1]== 1 and vote_list[index][2] == "xpendable_ran":
        item.append(xpendable_ran_list[0])
      if vote_list[index][1]== 2 and vote_list[index][2] == "xpendable_ran":
        item.append(xpendable_ran_list[1])
      if vote_list[index][1]== 3 and vote_list[index][2] == "xpendable_ran":
        item.append(xpendable_ran_list[2])
      if vote_list[index][1]== 4 and vote_list[index][2] == "xpendable_ran":
        item.append(xpendable_ran_list[3])
      if vote_list[index][1]== 5 and vote_list[index][2] == "xpendable_ran":
        item.append(xpendable_ran_list[4])
      if vote_list[index][1]== 6 and vote_list[index][2] == "xpendable_ran":
        item.append(xpendable_ran_list[5])
      if vote_list[index][1]== 1 and vote_list[index][2] == "xpendable_rna":
        item.append(xpendable_rna_list[0])
      if vote_list[index][1]== 2 and vote_list[index][2] == "xpendable_rna":
        item.append(xpendable_rna_list[1])
      if vote_list[index][1]== 3 and vote_list[index][2] == "xpendable_rna":
        item.append(xpendable_rna_list[2])
      if vote_list[index][1]== 4 and vote_list[index][2] == "xpendable_rna":
        item.append(xpendable_rna_list[3])
      if vote_list[index][1]== 5 and vote_list[index][2] == "xpendable_rna":
        item.append(xpendable_rna_list[4])
      if vote_list[index][1]== 6 and vote_list[index][2] == "xpendable_rna":
        item.append(xpendable_rna_list[5])
#Convert list to dataframe
    final_vote_df = pd.DataFrame(vote_list)
#Create a copy of dataframe and then rename columns
    renamed = final_vote_df.copy(deep=True)
    renamed.columns = ["Subject ID", "Round", "Coplayer", "Subject vote", "Coplayer vote"] 
#Write a CSV file
    renamed.to_csv(r'/content/drive/MyDrive/FYRE Behavior/test3.csv', 
                       index = False)
